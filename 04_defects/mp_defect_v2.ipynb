# %%
from ase.build import bulk

# %%
from mp_api.client import MPRester

# %%
from structuretoolkit.common import ase_to_pymatgen, pymatgen_to_ase

# %%
from structuretoolkit.visualize import plot3d

# %%
from pymatgen.analysis.defects.generators import VoronoiInterstitialGenerator

# %%
with MPRester("your API key") as mpr:
    structure = mpr.get_structure_by_material_id("mp-2151")
# Out:
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
plot3d(pymatgen_to_ase(structure))
# Out:
# /Users/janssen/mambaforge/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# NGLWidget()

# %%
result = VoronoiInterstitialGenerator().get_defects(structure, {"Fe"})
result
# Out:
# [Fe intersitial site at [0.44,0.44,0.00],
#  Fe intersitial site at [0.25,0.13,0.13],
#  Fe intersitial site at [0.21,0.21,0.09],
#  Fe intersitial site at [1.00,1.00,0.20],
#  Fe intersitial site at [0.25,0.50,0.75],
#  Fe intersitial site at [0.21,0.61,0.77],
#  Fe intersitial site at [0.40,0.85,0.80],
#  Fe intersitial site at [0.53,0.78,0.78],
#  Fe intersitial site at [0.49,0.74,0.85],
#  Fe intersitial site at [0.52,0.09,0.09],
#  Fe intersitial site at [0.83,0.22,0.22]]

# %%
plot3d(pymatgen_to_ase(result[0].defect_structure))
# Out:
# NGLWidget()

# %%
plot3d(pymatgen_to_ase(result[1].defect_structure))
# Out:
# NGLWidget()
